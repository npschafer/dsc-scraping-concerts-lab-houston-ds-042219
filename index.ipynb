# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
#Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_events(events_page_url):
    html_page = requests.get(events_page_url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    event_listing = soup.find('div', class_="fl col4")
    titles = [x.text.strip() for x in soup.select('h1.event-title')]
    dates = [x.text for x in event_listing.findAll('time')]
    span_list = event_listing.findAll('span')
    venues = [x.text.split('>')[0][3:] for x in span_list if "at " in x.text]
    attending = [int(x.text.split('>')[0][0]) for x in soup.findAll('p', class_="attending")]
    df = pd.DataFrame([titles, venues, dates, attending]).T
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
df = scrape_events("https://www.residentadvisor.net/events/us/newyork")

# %%
df
# Out:
#                                             Event_Name  \
# 0            Wave Sessions with Mala at The Brown Note
# 1    Body Music Therapy with Pure Immanence at Nowa...
# 2       MASHT NYC Feat. Talking Rings at Jupiter Disco
# 3    Tempo with Pablo Romero, Lorenzo Slider at TBA...
# 4                      Cipher at Bossa Nova Civic Club
# 5    Delivery. Henry Chow, Sveta Voice, Pjay, Bytz ...
# 6       Feel Real presents Going Places at Rumpus Room
# 7    Postponed Until Further Notice 51717, Huerco S...
# 8       Satori and the Band From Space at House Of Yes
# 9    Eamon & Justin, Soul Summit, Analog Soul, and ...
# 10   Effervescence // rrao, Yibing, Aquatic Themes,...
# 11   Cultivated Sound 05152019: Todd Sines, Katie R...
# 12   Red Bull Music Festival presents Teyana Taylor...
# 13                               Transmissions at H0L0
# 14                        Dance Dance Dance at Le Bain
# 15   PUBLIC ARTS & Soundchk present: Acid Mondays a...
# 16   So Natural x Ūndisclosed - Andres Rosero, Loga...
# 17   Erase The Light - Brian Thabault's EP Release ...
# 18   5/15-Expansions NYC Curated by DJ Louie Vega a...
# 19   Playroom: Isaiah Martin & Ana Boo at Electric ...
# 20   Morgana [free entry]: DJ Three, Doc Martin, Fo...
# 21   Wax Motif with Charles Meyer / Devon James - B...
# 22   Constant Motion: David Paglia - Amy Jor - Alex...
# 23   Anything Goes: The Martinez Brothers & Blas Co...
# 24   Satori & The Band From Space: Live in Concert ...
# 25   Micro Vision x Wex: Seemingly Normal People at...
# 26   Eamon & Justin, Soul Summit, Analog Soul, and ...
# 27   Red Bull Music Festival & Pioneer Works presen...
# 28   Let's Play House: L'amour Existe Encore at Le ...
# 29   Kontravoid, Multiple Man, Confines at Brooklyn...
# ..                                                 ...
# 110  PFR Live: Noah Prebish, Wandertalk, Juggable O...
# 111               Ibiza Lounge at Engine Room New York
# 112  Poprally presents Stranger Vibes: A Night of A...
# 113  House Music Happy Hour with DJ Mkhuseli at Bea...
# 114  Party Up Midnight Yacht Cruise at Harbor Light...
# 115  Dancinginthestreet: Dance Paradefloat: S.O.L.A...
# 116  Sole Rehab 042 - Signal Noise vs Sole Rehab at...
# 117  Harvard Bass, Alan Nieves, Dischetto at Sunnyvale
# 25                         TBA Brooklyn  2019-05-16T00:00                   1
# 26                       TBA - Brooklyn  2019-05-16T00:00                   6
# 27                        Pioneer Works  2019-05-16T00:00                   5
# 28                              Le Bain  2019-05-16T00:00                   5
# 29                      Brooklyn Bazaar  2019-05-16T00:00                   5
# ..                                  ...               ...                 ...
# 110                      TBA - New York  2019-05-18T00:00                None
# 111                Engine Room New York  2019-05-18T00:00                None
# 112            The Museum of Modern Art  2019-05-18T00:00                None
# 113                Bean & Barley Harlem  2019-05-18T00:00                None
# 114                 Harbor Lights Yacht  2019-05-18T00:00                None
# 115                      TBA - New York  2019-05-18T00:00                None
# 116  TBA - Rochester, Buffalo/Rochester  2019-05-18T00:00                None
# 117                           Sunnyvale  2019-05-18T00:00                None
# 118                      public records  2019-05-18T00:00                None
# 119                  Issue Project Room  2019-05-18T00:00                None
# 120                             Pier 40  2019-05-18T00:00                None
# 121                     Brooklyn Mirage  2019-05-19T00:00                None
# 122                 Circle Line Cruises  2019-05-19T00:00                None
# 123                            Nowadays  2019-05-19T00:00                None
# 124                    Knockdown Center  2019-05-19T00:00                None
# 125                           Elsewhere  2019-05-19T00:00                None
# 126                         Magick City  2019-05-19T00:00                None
# 127                            Nowadays  2019-05-19T00:00                None
# 128                          Polygon BK  2019-05-19T00:00                None
# 129                                H0L0  2019-05-19T00:00                None
# 130                                MoMA  2019-05-19T00:00                None
# 131         East River Park Ampitheatre  2019-05-19T00:00                None
# 132                        TBA Brooklyn  2019-05-19T00:00                None
# 133                             Le Bain  2019-05-19T00:00                None
# 134                             Club 57  2019-05-19T00:00                None
# 135                             Le Bain  2019-05-19T00:00                None
# 136                      public records  2019-05-19T00:00                None
# 137                  Chelsea Music Hall  2019-05-19T00:00                None
# 138                             Le Bain  2019-05-20T00:00                None
# 139                            Nowadays  2019-05-20T00:00                None
#
# [140 rows x 4 columns]

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    from urllib.parse import urljoin
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    next_page_url = [urljoin(url,x.get('href')) for x in soup.findAll('a') if "Next " in x.text][0]
    return next_page_url

# %%
next_page("https://www.residentadvisor.net/events/us/newyork")
# Out:
# 'https://www.residentadvisor.net/events/us/newyork/week/2019-05-21'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
def scrape_lots_of_events(starting_url, num_events_to_scrape=1000):
    url = starting_url
    df = pd.DataFrame()
    while len(df) < num_events_to_scrape:
        new_df = scrape_events(url)
        url = next_page(url)
        df = pd.concat([df, new_df])
    df.sort_values(by=['Number_of_Attendees', 'Event_Date'], inplace=True, ascending=False)
    df.reset_index(inplace=True)
    return df

# %%
df = scrape_lots_of_events("https://www.residentadvisor.net/events/us/newyork", num_events_to_scrape=1000)

# %%
len(df)

# %%
df.head()

# %%
df.tail()

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully scraped a website for concert event information!
